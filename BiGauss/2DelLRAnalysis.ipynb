# %%
from icecube import icetray, dataio, dataclasses, simclasses, clsim
from icecube.icetray import I3Units, OMKey, I3Frame
from icecube.dataclasses import ModuleKey
from os.path import expandvars
import scipy.constants as spc
import scipy as sc
import numpy as np
import matplotlib.pylab as plt
from scipy import stats
from scipy.optimize import minimize
from scipy.stats.distributions import chi2
import scipy

# %%
tau_allCharge = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin3.0_cmax_20.0_tau.csv')
e_allCharge = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin3.0_cmax_20.0_e.csv')
rejected_allCharge = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin3.0_cmax_20.0_rejected_.csv')
#percent_rej_allCharge = float(len(rejected_allCharge))/float((len(tau_allCharge)+len(e_allCharge)+len(rejected_allCharge)))*100
e_timeDiff_allCharge = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_timeDiff_cmin3.0_cmax_20.0_e.csv')
tau_timeDiff_allCharge = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_timeDiff_cmin3.0_cmax_20.0_tau.csv')

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_allCharge[tau_allCharge != float('inf')]), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_allCharge), normed=True, histtype='step', label = 'e & NC')
#plt.title('All Charges -- Rejected Events:'+str(round(percent_rej_allCharge))+'%', fontsize=18)
plt.title('All Charges', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize=16)

# %%
tau_1 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin3.8_cmax_4.5_tau.csv')
e_1 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin3.8_cmax_4.5_e.csv')
#rejected_1 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin3.8_cmax_4.5_rejected_.csv')
#percent_rej_1 = float(len(rejected_1))/float((len(tau_1)+len(e_1)+len(rejected_1)))*100

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_1), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_1), normed=True, histtype='step', label = 'e & NC')
#plt.title('NumHits:3.8-4.5 -- Rejected Events:'+str(round(percent_rej_1))+'%', fontsize=18)
plt.title('NumHits:3.8-4.5', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize=16)

# %%
tau_2 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin4.5_cmax_5.0_tau.csv')
e_2 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin4.5_cmax_5.0_e.csv')
#rejected_2 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin4.5_cmax_5.0_rejected_.csv')
#percent_rej_2 = float(len(rejected_2))/float((len(tau_2)+len(e_2)+len(rejected_2)))*100

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_2), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_2), normed=True, histtype='step', label = 'e & NC')
#plt.title('NumHits:4.5-5.0 -- Rejected Events:'+str(round(percent_rej_2))+'%', fontsize=18)
plt.title('NumHits:4.5-5.0', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize='16')

# %%
tau_3 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin5.0_cmax_5.5_tau.csv')
e_3 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin5.0_cmax_5.5_e.csv')
#rejected_3 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin5.0_cmax_5.5_rejected_.csv')
#percent_rej_3 = float(len(rejected_3))/float((len(tau_3)+len(e_3)+len(rejected_3)))*100

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_3), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_3), normed=True, histtype='step', label = 'e & NC')
#plt.title('NumHits:5.0-5.5 -- Rejected Events:'+str(round(percent_rej_3))+'%', fontsize=18)
plt.title('NumHits:5.0-5.5', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize='16')

# %%
tau_4 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin5.5_cmax_6.0_tau.csv')
e_4 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin5.5_cmax_6.0_e.csv')
#rejected_4 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin5.5_cmax_6.0_rejected_.csv')
#percent_rej_4 = float(len(rejected_4))/float((len(tau_4)+len(e_4)+len(rejected_4)))*100

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_4[tau_4 != float('inf')]), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_4), normed=True, histtype='step', label = 'e & NC')
#plt.title('NumHits:5.5-6.0 -- Rejected Events:'+str(round(percent_rej_4))+'%', fontsize=18)
plt.title('NumHits:5.5-6.0', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize='16')

# %%
tau_5 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin6.0_cmax_6.5_tau.csv')
e_5 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin6.0_cmax_6.5_e.csv')
#rejected_5 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin6.0_cmax_6.5_rejected_.csv')
#percent_rej_5 = float(len(rejected_5))/float((len(tau_5)+len(e_5)+len(rejected_5)))*100

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_5[tau_5 != float('inf')]), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_5), normed=True, histtype='step', label = 'e & NC')
#plt.title('NumHits:6.0-6.5 -- Rejected Events:'+str(round(percent_rej_5))+'%', fontsize=18)
plt.title('NumHits:6.0-6.5', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize='16')

# %%
tau_6 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin6.5_cmax_7.0_tau.csv')
e_6 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLRall_cmin6.5_cmax_7.0_e.csv')
rejected_6 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin6.5_cmax_7.0_rejected_.csv')
percent_rej_6 = float(len(rejected_6))/float((len(tau_6)+len(e_6)+len(rejected_6)))*100

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_6[tau_6 != float('inf')]), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_6), normed=True, histtype='step', label = 'e & NC')
#plt.title('NumHits:6.5-7.0 -- Rejected Events:'+str(round(percent_rej_6))+'%', fontsize=18)
plt.title('NumHits:6.5-7.0', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize='16')

# %%
tau_7 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin7.0_cmax_7.5_tau.csv')
e_7 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin7.0_cmax_7.5_e.csv')
rejected_7 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin7.0_cmax_7.5_rejected_.csv')
percent_rej_7 = float(len(rejected_7))/float((len(tau_7)+len(e_7)+len(rejected_7)))*100

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_7[tau_7 != float('inf')]), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_7), normed=True, histtype='step', label = 'e & NC')
plt.title('NumHits:7.0-7.5 -- Rejected Events:'+str(round(percent_rej_7))+'%', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize='16')

# %%
tau_8 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin7.5_cmax_8.0_tau.csv')
e_8 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin7.5_cmax_8.0_e.csv')
rejected_8 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin7.5_cmax_8.0_rejected_.csv')
percent_rej_8 = float(len(rejected_8))/float((len(tau_8)+len(e_8)+len(rejected_8)))*100

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_8[tau_8 != float('inf')]), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_8), normed=True, histtype='step', label = 'e & NC')
plt.title('NumHits:7.5-8.0 -- Rejected Events:'+str(round(percent_rej_8))+'%', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize='16')
# Out:
# /cvmfs/icecube.opensciencegrid.org/py2-v3.1.1/RHEL_7_x86_64/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: loadtxt: Empty input file: "/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin7.5_cmax_8.0_tau.csv"
#   """Entry point for launching an IPython kernel.

# %%
tau_9 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin8.0_cmax_8.5_tau.csv')
e_9 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin8.0_cmax_8.5_e.csv')
rejected_9 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin8.0_cmax_8.5_rejected_.csv')
percent_rej_9 = float(len(rejected_9))/float((len(tau_9)+len(e_9)+len(rejected_9)))*100

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_9[tau_9 != float('inf')]), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_9), normed=True, histtype='step', label = 'e & NC')
plt.title('NumHits:8.0-8.5 -- Rejected Events:'+str(round(percent_rej_9))+'%', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize='16')

# %%
tau_10 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin8.5_cmax_9.0_tau.csv')
e_10 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin8.5_cmax_9.0_e.csv')
rejected_10 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin8.5_cmax_9.0_rejected_.csv')
percent_rej_10 = float(len(rejected_10))/float((len(tau_10)+len(e_10)+len(rejected_10)))*100

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_10[tau_10 != float('inf')]), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_10), normed=True, histtype='step', label = 'e & NC')
plt.title('NumHits:8.5-9.0 -- Rejected Events:'+str(round(percent_rej_10))+'%', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize='16')
# Out:
# /cvmfs/icecube.opensciencegrid.org/py2-v3.1.1/RHEL_7_x86_64/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: loadtxt: Empty input file: "/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin8.5_cmax_9.0_tau.csv"
#   """Entry point for launching an IPython kernel.

# %%
tau_11 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin9.0_cmax_9.5_tau.csv')
e_11 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin9.0_cmax_9.5_e.csv')
rejected_11 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin9.0_cmax_9.5_rejected_.csv')
percent_rej_11 = float(len(rejected_11))/float((len(tau_11)+len(e_11)+len(rejected_11)))*100

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_11[tau_11 != float('inf')]), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_11), normed=True, histtype='step', label = 'e & NC')
plt.title('NumHits:9.0-9.5 -- Rejected Events:'+str(round(percent_rej_11))+'%', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize='16')

# %%
tau_12 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin9.5_cmax_12.0_tau.csv')
e_12 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin9.5_cmax_12.0_e.csv')
rejected_12 = np.loadtxt('/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_cmin9.5_cmax_12.0_rejected_.csv')
percent_rej_12 = float(len(rejected_12))/float((len(tau_12)+len(e_12)+len(rejected_12)))*100

plt.figure(figsize=(10,9))
plt.hist(np.log10(tau_12[tau_12 != float('inf')]), normed=True, histtype='step', label = 'tau')
plt.hist(np.log10(e_12), normed=True, histtype='step', label = 'e & NC')
plt.title('NumHits:9.5-12.0 -- Rejected Events:'+str(round(percent_rej_12))+'%', fontsize=18)
plt.xlabel('log10(Del Likelihood Ratio)', fontsize = 16)
plt.legend(fontsize='16')
# Out:
# /cvmfs/icecube.opensciencegrid.org/py2-v3.1.1/RHEL_7_x86_64/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: loadtxt: Empty input file: "/data/p-one/akatil/analysis/NuTau_NuE_20Events_allCharge_2DelLLR_cmin9.5_cmax_12.0_tau.csv"
#   """Entry point for launching an IPython kernel.

# %%
from icecube import icetray, dataio, dataclasses, simclasses, clsim
from icecube.icetray import I3Units, OMKey, I3Frame
from icecube.dataclasses import ModuleKey
from os.path import expandvars
import numpy as np
#import matplotlib.pylab as plt
#import argparse
from scipy import stats
from scipy.optimize import minimize
from scipy.stats.distributions import chi2
import scipy
from likelihoodRatioAnalysis import likelihoodfit

#file = dataio.I3File(str(infile))
#parser = argparse.ArgumentParser(description = "Likelihood analysis")
#parser.add_argument('-cmin', '--min_charge', dest = 'cmin', help= 'Minimum charge of the events')
#parser.add_argument('-cmax', '--max_charge', dest = 'cmax', help= 'Maximum charge of the events')
#args = parser.parse_args()

gcd_file = dataio.I3File('/home/users/akatil/P-ONE/GCD_files/PONE_Phase1.i3.gz')
cframe = gcd_file.pop_frame()
geometry = cframe["I3Geometry"]
omgeo = geometry.omgeo
print('loaded geometry')

tauLLR = ([])
eLLR = ([])

tauLLR2 = ([])
eLLR2 = ([])

tauLLR3 = ([])
eLLR3 = ([])

tauTimeDiff = ([])
eTimeDiff = ([])

rejected = ([])
for i in range(0, 2000):
    print(i)
    file = dataio.I3File('/data/p-one/akatil/step_4_medium_water/NuTau_NuE_20Events/step_4_'+str(i)+'_medium_water_custom_mDOM_noise.i3.gz')

    for frame in file:
        print('Starting')
        numHitsinDOM = ([])
        numHits = ([])
        mctree = frame["I3MCTree"]
        primary = mctree.primaries
        lepton = dataclasses.I3MCTree.first_child(mctree, primary[0].id)

        mcpeMap = frame['MCPESeriesMap']
        noiseMap = frame['NoiseSeriesMap']

        #looping through doms that have physics hits
        for omkey in mcpeMap.keys():
            oKey = omgeo.get(omkey)

            '''
            Obtaining the timeList
            '''
            noise_mcpeList = noiseMap[omkey]
            noise_timeList = np.array([mcpe.time for mcpe in noise_mcpeList])
            mcpeList = mcpeMap[omkey]
            timeList = np.array([mcpe.time for mcpe in mcpeList])
            tot_timeList = np.append(timeList, noise_timeList)
            numHitsinDOM = np.append(tot_timeList, noise_timeList)

            #print(numHitsinDOM)

        numHits = np.append(numHits, sum(numHitsinDOM))
        log_numHits = np.log10(numHits[numHits > 0])
        print(log_numHits)
        if log_numHits >= float(9.5) and log_numHits < float(12.0):
            val, timeDiff, val2, string = likelihoodfit(frame, omgeo)
            if string == 'tau':
                tauLLR = np.append(tauLLR, val)
                tauLLR2 = np.append(tauLLR2, val2)
                tauTimeDiff = np.append(tauTimeDiff, timeDiff)
            if string == 'e':
                eLLR = np.append(eLLR, val)
                eLLR2 = np.append(eLLR2, val2)
                eTimeDiff = np.append(eTimeDiff, timeDiff)
            if string == 'rejected events':
                rejected = np.append(rejected, val)
# Out:
# loaded geometry
# 0
# Starting
# [5.33727169]
# Starting
# [5.5625788]
# Starting
# [4.88557688]
# Starting
# [4.9967984]
# Starting
# [8.66875003]
# Starting
# [5.68705231]
# Starting
# [5.40682639]
# Starting
# [8.79263322]
# Starting
# [5.14676398]
# Starting
# [8.85459341]
# Starting
# [5.45707489]
# Starting
# [5.5450921]
# Starting
# [8.30604514]
# Starting
# [4.88026072]
# Starting
# [5.26333005]
# Starting
# [5.26288539]
# 1
# Starting
# [5.02375786]
# Starting
# [8.32451256]
# Starting
# [6.39512534]
# Starting
# [7.92016177]
# Starting
# [4.17715353]
# Starting
# [5.20154682]
# Starting
# [5.05308756]
# Starting
# [5.02010919]
# Starting
# [5.49466588]
# Starting
# [4.67057161]
# Starting
# [8.1514889]
# Starting
# [7.95092167]
# Starting
# [7.5522464]
# Starting
# [6.74650305]
# Starting
# [8.46184613]
# Starting
# [4.37621352]
# Starting
# [8.13258792]
# 2
# Starting
# [5.90510605]
# Starting
# [9.04072742]
# Starting
# [6.12718781]
# Starting
# [5.88048809]
# Starting
# ...
